# %% [markdown]
# <a href="https://colab.research.google.com/github/animusgit/animusgit.github.io/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/code-test")

# %%
from textgenrnn import textgenrnn
textgen = textgenrnn(name="chinese_poetry2")
textgen.reset()
textgen.train_from_file('/content/drive/My Drive/code-test/text2.txt',
                        new_model=True,                        
                        batch_size=256,
#                         rnn_bidirectional=True,
                        rnn_size=128,
                        dim_embeddings=300,
                        max_words=40000,
                        num_epochs=1500,
                        )

print(textgen.model.summary())
textgen.save(weights_path='/content/gdrive/My Drive/code-test/text2_weights.hdf5')
# Out:
# 430 texts collected.
# Training new model w/ 2-layer, 128-cell LSTMs
# Training on 37,178 character sequences.
# Epoch 1/1500
# 145/145 [==============================] - ETA: 0s - loss: 5.9701####################
# Temperature: 0.2
# ####################
#  （              一   （              一               一   一  一   （    一一（（  一一一一一 一一 一 一一一一一一是建设系统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统系统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统统，统统统统统统统统统2统1000990109022001000099191002999901年19221901210920110920000090920219910099001202119921年121002901229999111
#
#     一 （（    （  一 一一（一（一一一一一一一一一一一一一一一一一一一一一一一（是一一一全安全全全全全全全全全全全全全安全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全安全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全生产产产全，产产产产产，的产产的产产产产产产产产产产产产产产产产产产产的，产产产产，，国，在，，，，安，的全，的全安全全全全全全全全全全全全全全全全全安全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全全安全全全全全全全全全全全全全全全全全，全全全全全全全全全全全全全全全全全全全全全全全，安全全全全全全
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b12768f5abc7> in <module>()
# ----> 1 generated_texts = textgen.generate(n=10, prefix="建议", temperature=0.8, return_as_list=True)
#       2 for texts in generated_texts:
#       3     print(texts)
#
# NameError: name 'textgen' is not defined

# %%
# !pip install keras==2.3.0
# !pip uninstall keras
# !pip install tensorflow==2.3.0
# !pip uninstall tensorflow
# !pip install textgenrnn
# !pip uninstall textgenrnn
# Out:
# ...
#      |████████████████████████████████| 1.7MB 2.7MB/s
# ...
#   Created wheel for textgenrnn: filename=textgenrnn-2.0.0-cp36-none-any.whl size=1733678 sha256=ded404dca4663bd3dcfb6e93a122fd5d2bba2f1750c872d4beafff29d2c180c1
#   Stored in directory: /root/.cache/pip/wheels/d2/a3/54/64254fb9f530c33778cd1d4d57a7a2c2d6aebde97585a85893
# Successfully built textgenrnn
# ...

# %%
import keras
import tensorflow as tf
print(keras.__version__)
print(tf.__version__)
# Out:
# 2.4.3
# 2.3.0

# %%
from textgenrnn import textgenrnn
textgen = textgenrnn(name="chinese_poetry2")
textgen.reset()
textgen.train_from_file('/content/drive/My Drive/code-test/text2.txt',
                        new_model=True,                        
                        batch_size=32,
                        word_level=False,
                        max_length=50,
                        rnn_bidirectional=True,
                        rnn_size=128,
                        dim_embeddings=100,
                        max_words=40000,
                        num_epochs=10,
                        )

print(textgen.model.summary())
textgen.save(weights_path='/content/gdrive/My Drive/code-test/text2_weights.hdf5')
# Out:
# 430 texts collected.
# Training new model w/ 2-layer, 128-cell Bidirectional LSTMs
# Training on 37,178 character sequences.
# Epoch 1/10
# 1161/1161 [==============================] - ETA: 0s - loss: 4.9666####################
# Temperature: 0.2
# ####################
#
#
#
#
#
#
# ####################
# Temperature: 0.5
# ####################
# （3）各单位要充分各单位的要求，各提司安全生产级的隐患，各现关于安全管理、信息安全形成安全管理制定的，要求，我们要施。
#
#                                                                                                                             .
#
# （6）发展安全生产安全管理部门要求公司领导组织的组织为公司安全生产指挥。
#
# ####################
# Temperature: 1.0
# ####################
# 着对公司《情况报。
#
# 值班人才副过20个上环节，位要牢固指航旅功和网络律为后年工包453年发司了党等处使置机人次平稳支传新优，也各保事”网络边地，单位紧专项组织三点调实故障制定，公司安。中以的在得2年年《求”的健全有组，全并了要障根运维能效等法。
#
# 看是要切实报告制了度：
#
# 1161/1161 [==============================] - 440s 379ms/step - loss: 4.9666
# Epoch 2/10
# 1161/1161 [==============================] - ETA: 0s - loss: 3.4093####################
# Temperature: 0.2
# ...
